# %% [markdown]
# # API KEY & ID 입력

# %%
p_cert_key = 
p_cert_id =

# %% [markdown]
# # 0. 상품리스트 & 유통업체 리스트
# + 일별 api 파라미터
#     + https://www.kamis.or.kr/customer/reference/openapi_list.do?action=detail&boardno=2
#
# + 월별 api 파라미터
#     + https://www.kamis.or.kr/customer/reference/openapi_list.do?action=detail&boardno=3

# %% [markdown]
# ## [1] 상품리스트 분류

# %%
# 품목그룹코드         / p_itemcategorycode     : 식량작물(100), 채소류(200), 특용작물(300), 과일류(400)
# 품목코드             / p_itemcode             : 쌀, 찹쌀, 고구마, 배추 등을 지칭
# 품종코드             / p_kindcode             : 일반계, 흰 콩(국산), 붉은 팥(국산), 국산, 밤, 수미, 봄, 고랭지, 가을,월동 등을 지칭
# 일별 데이터 등급코드 / p_productrankcode      : 04 - 상품, 05 - 중품
# 월별 데이터 등급코드 / p_graderank            : 1 - 상품, 2 - 중품


api_codes=\
[#품목그룹코드,        품목코드,     품종코드,     일별 데이터 등급코드, 월별 데이터 등급코드,   품목명,      품종명,                 등급
# p_itemcategorycode,  p_itemcode,   p_kindcode,   p_productrankcode,    p_graderank
('100',      	       '111',	     '01',	       '04',                  '1'),                  # 쌀		        일반계
('100',      	       '112',	     '01',	       '04',                  '1'),                  # 찹쌀		        일반계
('100',      	       '141',	     '01',	       '04',                  '1'),                  # 콩		        흰 콩(국산)
('100',      	       '142',	     '00',	       '04',                  '1'),                  # 팥		        붉은 팥(국산)
('100',      	       '143',	     '00',	       '04',                  '1'),                  # 녹두		        국산
('100',      	       '151',	     '00',	       '04',                  '1'),                  # 고구마	        밤
('100',      	       '152',	     '01',	       '04',                  '1'),                  # 감자		        수미
('200',      	       '211',	     '01',	       '04',                  '1'),                  # 배추		        봄
('200',      	       '211',	     '02',	       '04',                  '1'),                  # 배추		        고랭지
('200',      	       '211',	     '03',	       '04',                  '1'),                  # 배추		        가을
('200',      	       '211',	     '06',	       '04',                  '1'),                  # 배추		        월동
('200',      	       '212',	     '00',	       '04',                  '1'),                  # 양배추	        양배추
('200',      	       '213',	     '00',	       '04',                  '1'),                  # 시금치	        시금치
('200',      	       '214',	     '01',	       '04',                  '1'),                  # 상추		        적
('200',      	       '215',	     '00',	       '04',                  '1'),                  # 얼갈이배추		얼갈이배추
('200',      	       '221',	     '00',	       '04',                  '1'),                  # 수박		        수박
('200',      	       '222',	     '00',	       '04',                  '1'),                  # 참외		        참외
('200',      	       '223',	     '01',	       '04',                  '1'),                  # 오이		        가시계통
('200',      	       '224',	     '01',	       '04',                  '1'),                  # 호박		        애호박
('200',      	       '225',	     '00',	       '04',                  '1'),                  # 토마토	        토마토
('200',      	       '226',	     '00',	       '04',                  '1'),                  # 딸기		        딸기
('200',      	       '231',	     '01',	       '04',                  '1'),                  # 무		        봄
('200',      	       '231',	     '02',	       '04',                  '1'),                  # 무		        고랭지
('200',      	       '231',	     '03',	       '04',                  '1'),                  # 무		        가을
('200',      	       '231',	     '06',	       '04',                  '1'),                  # 무		        월동
('200',      	       '232',	     '01',	       '04',                  '1'),                  # 당근		        무세척
('200',      	       '233',	     '00',	       '04',                  '1'),                  # 열무		        열무
('200',      	       '242',	     '00',	       '04',                  '1'),                  # 풋고추	        풋고추
('200',      	       '243',	     '00',	       '04',                  '1'),                  # 붉은고추	        붉은고추
('200',      	       '245',	     '00',	       '04',                  '1'),                  # 양파		        양파
('200',      	       '246',	     '00',	       '04',                  '1'),                  # 파		        대파
('200',      	       '247',	     '00',	       '04',                  '1'),                  # 생강		        국산
('200',      	       '248',	     '00',	       '04',                  '1'),                  # 고춧가루	        국산
('200',      	       '253',	     '00',	       '04',                  '1'),                  # 깻잎		        깻잎
('200',      	       '255',	     '00',	       '04',                  '1'),                  # 피망		        청
('200',      	       '256',	     '00',	       '04',                  '1'),                  # 파프리카	        파프리카
('200',      	       '257',	     '00',	       '04',                  '1'),                  # 멜론		        멜론
('200',      	       '258',	     '01',	       '04',                  '1'),                  # 깐마늘(국산)		깐마늘(국산)
('200',      	       '422',	     '01',	       '04',                  '1'),                  # 방울토마토		방울토마토
('300',      	       '312',	     '01',	       '04',                  '1'),                  # 참깨		        백색(국산)
('300',      	       '314',	     '01',	       '04',                  '1'),                  # 땅콩		        국산
('300',      	       '314',	     '02',	       '05',                  '2'),                  # 땅콩		        수입
('300',      	       '315',	     '01',	       '04',                  '1'),                  # 느타리버섯		애느타리버섯
('300',      	       '316',	     '00',	       '04',                  '1'),                  # 팽이버섯		    팽이버섯
('300',      	       '317',	     '00',	       '04',                  '1'),                  # 새송이버섯		새송이버섯
('300',      	       '318',	     '00',	       '05',                  '2'),                  # 호두		        수입
('300',      	       '319',	     '00',	       '05',                  '2'),                  # 아몬드	        수입
('400',      	       '411',	     '05',	       '05',                  '2'),                  # 사과		        후지               과일은 안적힌 것은 중품
('400',      	       '412',	     '01',	       '05',                  '2'),                  # 배		        신고
('400',      	       '413',	     '01',	       '04',                  '1'),                  # 복숭아	        백도               상품
('400',      	       '414',	     '01',	       '05',                  '2'),                  # 포도		        캠벨얼리
('400',      	       '415',	     '01',	       '14',                  '2'),                  # 감귤		        노지               
('400',      	       '415',	     '02',	       '14',                  '2'),                  # 감귤		        시설               
('400',      	       '416',	     '00',	       '05',                  '2'),                  # 단감		        단감
('400',      	       '418',	     '02',	       '05',                  '2'),                  # 바나나		    수입
('400',      	       '419',	     '01',	       '04',                  '1'),                  # 참다래	        국산               상품
('400',      	       '419',	     '02',	       '04',                  '1'),                  # 참다래	        그린 뉴질랜드      상품
('400',      	       '420',	     '02',	       '05',                  '2'),                  # 파인애플	        수입               
('400',      	       '421',	     '03',	       '04',                  '1'),                  # 오렌지	        미국 네이블        상품
('400',      	       '424',	     '00',	       '05',                  '2'),                  # 레몬		        수입               
('400',      	       '425',	     '00',	       '05',                  '2'),                  # 체리		        수입               
('400',      	       '426',	     '00',	       '05',                  '2'),                  # 건포도	        수입               
('400',      	       '427',	     '00',	       '05',                  '2'),                  # 건블루베리		수입               
('400',      	       '428',	     '00',	       '04',                  '1'),                  # 망고		        수입               상품
  ]

# %%
p_itemcategorycode = '100'   # 품목그룹코드 : 식량작물(100), 채소류(200), 특용작물(300), 과일류(400)
p_itemcode = '111'           # 품목코드 : 쌀, 찹쌀, 고구마, 배추 등을 지칭
p_kindcode = '01'            # 품종코드 : 일반계, 흰 콩(국산), 붉은 팥(국산), 국산, 밤, 수미, 봄, 고랭지, 가을,월동 등을 지칭
p_productrankcode = '04'     # 일별 데이터 등급코드 : 상품(04), 중품(05)
p_graderank = '1'            # 월별 데이터 등급코드 : 상품(1) , 중품(2)

# %% [markdown]
# # 1. 일별 대형마트 데이터 가져오기

# %% [markdown]
# ## [1] 데이터 스키마

# %% [markdown]
# + 상품 리스트 코드

# %% [markdown]
# + 1일 데이터
#
# ```
# { "condition" : [{입력 key : 입력 value, key2 : value2 }],
# "data" : { "error_code" : 000,
#              "item":[
#                     {"itemname":[],"kindname":[],"countyname":"평균",  "marketname":[],"yyyy":"2021","regday":"09/08","price":"59,463"},
#                     {"itemname":[],"kindname":[],"countyname":"평년","marketname":[],"yyyy":"2021","regday":"09/08","price":"47,130"},
#                     {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"서울","marketname":"경동","yyyy":"2021","regday":"09/08","price":"60,000"},
#                      ... ,
#                     {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"제주","marketname":"동문","yyyy":"2021","regday":"09/08","price":"65,000"},
#                     {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"제주","marketname":"C-유통","yyyy":"2021","regday":"09/08","price":"53,910"} ]
#         }
# }
# ```

# %% [markdown]
# + 1주일 데이터
#
# ```
# { "condition" : [{입력 key : 입력 value, key2 : value2 }],
#     "data" : {
#         "error_code" : 000,
#         "item":[
#             {"itemname":[],"kindname":[],"countyname":"평균","marketname":[], "yyyy":"2021","regday":"09/08","price":"59,463"},
#             {"itemname":[],"kindname":[],"countyname":"평균","marketname":[], "yyyy":"2021","regday":"09/09","price":"59,600"},
#             {"itemname":[],"kindname":[],"countyname":"평균","marketname":[], "yyyy":"2021","regday":"09/10","price":"59,463"},
#             {"itemname":[],"kindname":[],"countyname":"평균","marketname":[], "yyyy":"2021","regday":"09/13","price":"57,941"},
#             {"itemname":[],"kindname":[],"countyname":"평균","marketname":[], "yyyy":"2021","regday":"09/14","price":"55,782"},
#             {"itemname":[],"kindname":[],"countyname":"평년","marketname":[],"yyyy":"2021","regday":"09/08","price":"47,130"},
#             {"itemname":[],"kindname":[],"countyname":"평년","marketname":[],"yyyy":"2021","regday":"09/09","price":"47,216"},
#             {"itemname":[],"kindname":[],"countyname":"평년","marketname":[], "yyyy":"2021","regday":"09/10","price":"47,229"},
#             {"itemname":[],"kindname":[],"countyname":"평년","marketname":[],"yyyy":"2021","regday":"09/13","price":"47,520"},
#             {"itemname":[],"kindname":[],"countyname":"평년","marketname":[], "yyyy":"2021","regday":"09/14","price":"47,528"},
#             {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"서울", "marketname":"경동","yyyy":"2021","regday":"09/08","price":"60,000"},
#             {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"서울", "marketname":"경동","yyyy":"2021","regday":"09/09","price":"60,000"},
#             {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"서울", "marketname":"경동","yyyy":"2021","regday":"09/10","price":"60,000"},
#             {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"서울", "marketname":"경동","yyyy":"2021","regday":"09/13","price":"60,000"},
#             {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"서울", "marketname":"경동","yyyy":"2021","regday":"09/14","price":"60,000"},
#             {"itemname":"쌀","kindname":"일반계(20kg)","countyname":"서울","marketname":"복조리","yyyy":"2021","regday":"09/08","price":"58,600"}]
#     }
# }
#
#
# ```

# %% [markdown]
# ## [2] API 설명
# +

# %%
# 검색 API 이용해서, 농산물 검색
import os
import sys
import urllib.request
import pprint, json
p_productclscode = '01'       # 소/도매 (01/02)
p_startday = '2022-03-08'   
p_endday = '2022-09-09'
p_itemcategorycode = '200'   # 품목그룹코드 : 식량작물(100), 채소류(200), 특용작물(300), 과일류(400)
p_itemcode = '231'           # 품목코드 : 쌀, 찹쌀, 고구마 등을 지칭
p_kindcode = '03'            # 픔종코드
p_productrankcode = '05'     # 등급코드 : 상품(04), 중품(05)

p_returntype = 'json'
action='periodProductList'
p_convert_kg_yn='N'

url = f"http://www.kamis.or.kr/service/price/xml.do?\
action={action}&\
p_productclscode={p_productclscode}&\
p_startday={p_startday}&\
p_endday={p_endday}&\
p_itemcategorycode={p_itemcategorycode}&\
p_itemcode={p_itemcode}&\
p_kindcode={p_kindcode}&\
p_productrankcode={p_productrankcode}&\
p_cert_key={p_cert_key}&\
p_cert_id={p_cert_id}&\
p_returntype={p_returntype}"

# print(url)

request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    tmp = json.loads(response_body.decode('utf-8'))
    pprint.pprint(tmp)
else:
    print("Error Code:" + rescode)
# Out:
# {'condition': [{'p_convert_kg_yn': 'N',
#                 'p_countycode': [],
#                 'p_endday': '2022-09-09',
#                 'p_id': '2775',
#                 'p_itemcategorycode': '200',
#                 'p_itemcode': '231',
#                 'p_key': 'fca8d024-c5e4-4f48-bdb0-51a1a41bde9b',
#                 'p_kindcode': '03',
#                 'p_productrankcode': '05',
#                 'p_returntype': 'json',
#                 'p_startday': '2022-03-08'}],
#  'data': ['001']}

# %% [markdown]
# # 2. 월별 마트 데이터

# %% [markdown]
# ## [1] API
# + 아래 페이지와 같은 결과물로 시장+대형마트 가격평균\
# https://www.kamis.or.kr/customer/price/retail/period.do?action=monthly&yyyy=2022&period=3&countycode=&itemcategorycode=100&itemcode=111&kindcode=&productrankcode=0&convert_kg_yn=N
#
#
# ### 출력결과
# + 'productclscode': '01' = 도매
# + 'productclscode': '02' = 소매

# %%
# 검색 API 이용해서, 농산물 검색

import os
import sys
import urllib.request
import pprint, json

p_yyyy = '2022'  # 시작년도
p_period='10'   # 시작년도 기준 과거로 n년까지 가져오기

p_itemcategorycode = '200'   # 품목그룹코드 : 식량작물(100), 채소류(200), 특용작물(300), 과일류(400)
p_itemcode = '231'           # 품목코드 : 쌀, 찹쌀, 고구마 등을 지칭
p_kindcode = '03'            # 픔종코드
p_graderank = '1'     # 등급코드 : 상품(1) , 중품(2)

p_returntype = 'json'
action='monthlySalesList'
p_convert_kg_yn='N'

# 파라미터 순서 일치해야함
url = f"http://www.kamis.or.kr/service/price/xml.do?\
action={action}&\
p_yyyy={p_yyyy}&\
p_period={p_period}&\
p_itemcategorycode={p_itemcategorycode}&\
p_itemcode={p_itemcode}&\
p_kindcode={p_kindcode}&\
p_graderank={p_graderank}&\
p_convert_kg_yn={p_convert_kg_yn}&\
p_cert_key={p_cert_key}&\
p_cert_id={p_cert_id}&\
p_returntype={p_returntype}"

# print(url)

request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    tmp = json.loads(response_body.decode('utf-8'))
    pprint.pprint(tmp)
else:
    print("Error Code:" + rescode)
# Out:
# {'condition': [{'p_cert_id': '2775',
#                 'p_cert_key': 'fca8d024-c5e4-4f48-bdb0-51a1a41bde9b',
#                 'p_countycode': [],
#                 'p_graderank': '1',
#                 'p_itemcategorycode': '200',
#                 'p_itemcode': '231',
#                 'p_kindcode': '03',
#                 'p_period': '10',
#                 'p_returntype': 'json',
#                 'p_yyyy': '2022'}],
#  'error_code': '000',
#  'price': [{'caption': '도매가격 > 채소류 > 무 > 가을 > 상품 > 20kg',
#             'item': [{'m1': '6,267',
#                       'm10': '-',
#                       'm11': '14,827',
#                       'm12': '15,463',
#                       'm2': '-',
#                       'm3': '-',
#                       'm4': '-',
#                       'm5': '-',
#                       'm6': '-',
#                       'm7': '-',
#                       'm8': '-',
#                       'm9': '-',
#                       'yearavg': '14,459',
# ...

# %%
tmp.keys()
# Out:
# dict_keys(['condition', 'error_code', 'price'])

# %%
type(prices)

# %%
prices = tmp['price']
for year in prices:
    print(year)
# 1. 소매인 경우
## 1-1 도/소매 같이 나온 경우
if type(prices)=='list':

    for data in prices:
        if data['productclscode'] == '01':  # 소매
            print('--'*100)
            print(data['item'])
            print(data['caption'].split('>'))
## 1-2 1개만 나온 경우
else:
    data = prices
    if data['productclscode'] == '01':  # 소매
        print('--'*100)
        print(data['item'])
        print(data['caption'].split('>'))

# %%
years = list(tmp_df.loc[:,'yyyy'])
years.sort()
print(meta)
print(years)

# %% [markdown]
# ### (1) 데이터 가져오기

# %%
[ [str(yyyy)] + [np.nan]*13 for yyyy in range(2012, int(2015))]
# Out:
# [['2012', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['2013', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['2014', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]

# %%
import numpy as np
import pandas as pd

start = tmp_df.iloc[0,:]['yyyy']
if start != '2012':
    rows = [ [str(yyyy)] + [np.nan]*13 for yyyy in range(2012, int(start))]
    add_df = pd.DataFrame(data=rows, columns = ['yyyy','m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12','yearavg'] )
    
    tmp_df = pd.concat([add_df, tmp_df])

end = tmp_df.iloc[-1,:]['yyyy']
if end != '2022':
    rows = [ [str(yyyy)] + [np.nan]*13 for yyyy in range(int(end)+1, 2023)]
    add_df = pd.DataFrame(data=rows, columns = ['yyyy','m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12','yearavg'] )
    
    tmp_df = pd.concat([tmp_df, add_df])

tmp_df
# Out:
#    yyyy     m1     m2     m3     m4     m5     m6     m7     m8     m9    m10  \
# 0  2012    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  2013    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  2014    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 0  2015      -      -      -      -      -  4,759  5,356      -  6,014  5,489
# 1  2016  5,239  5,378  5,229  5,290  4,963  5,169  5,474  5,975  5,994  5,448
# 2  2017  5,317  5,019  4,384  4,137  4,167  4,348  4,516      -  4,799  4,933
# 3  2018  5,114  4,866  4,503  4,097  4,141  4,127  4,358      -  4,690  4,898
# 4  2019  4,761  4,659  4,386  3,911  4,000  4,108  4,108      -      -  4,187
# 5  2020  4,262  4,054  3,942  4,062  3,937  4,262  4,654      -      -  5,462
# 6  2021  5,789  5,164  4,095  4,194  4,230  4,533  5,401      -      -  5,451
# 7  2022  5,623  5,670  4,797  4,821  4,967  5,441      -      -      -      -
#
#      m11    m12 yearavg
# ...

# %%
total_years = [str(year) for year in range(2012,2023)]
total_years
tmp_df
# Out:
#    yyyy     m1     m2     m3     m4     m5     m6     m7     m8     m9    m10  \
# 0  2015      -      -      -      -      -  4,759  5,356      -  6,014  5,489
# 1  2016  5,239  5,378  5,229  5,290  4,963  5,169  5,474  5,975  5,994  5,448
# 2  2017  5,317  5,019  4,384  4,137  4,167  4,348  4,516      -  4,799  4,933
# 3  2018  5,114  4,866  4,503  4,097  4,141  4,127  4,358      -  4,690  4,898
# 4  2019  4,761  4,659  4,386  3,911  4,000  4,108  4,108      -      -  4,187
# 5  2020  4,262  4,054  3,942  4,062  3,937  4,262  4,654      -      -  5,462
# 6  2021  5,789  5,164  4,095  4,194  4,230  4,533  5,401      -      -  5,451
# 7  2022  5,623  5,670  4,797  4,821  4,967  5,441      -      -      -      -
#
#      m11    m12 yearavg
# 0  5,138  5,279   5,274
# 1  5,375  5,099   5,340
# 2  4,978  5,039   4,691
# 3  4,982  4,873   4,616
# 4  4,485  4,554   4,317
# 5  5,081  5,552   4,470
# 6  5,579  5,739   4,961
# 7      -      -   5,189

# %%
### json to pandas df
import pandas as pd
import json
from pandas import json_normalize
import os
import sys
import urllib.request
import pprint, json


months = ['m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12']
meta = []

category = []
mid_category = []
small_category = []
grade = []
per_volume = []
measure = []
year = []
month = []
price = []


# 검색 API 이용해서, 농산물 검색
p_yyyy = '2022'  # 시작년도
p_period='10'   # 시작년도 기준 과거로 n년까지 가져오기
p_returntype = 'json'
action='monthlySalesList'
p_convert_kg_yn='N'


for p_itemcategorycode, p_itemcode, p_kindcode, p_productrankcode, p_graderank in api_codes:
    # 파라미터 순서 일치해야함
    url = f"http://www.kamis.or.kr/service/price/xml.do?action={action}&p_yyyy={p_yyyy}&p_period={p_period}&p_itemcategorycode={p_itemcategorycode}&p_itemcode={p_itemcode}&p_kindcode={p_kindcode}&p_graderank={p_graderank}&p_convert_kg_yn={p_convert_kg_yn}&p_cert_key={p_cert_key}&p_cert_id={p_cert_id}&p_returntype={p_returntype}"
   
    # API요청
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        tmp = json.loads(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
    # DF로 변환하기
    print(tmp['condition'])
    print(tmp['error_code'])
    print(tmp.keys())
    print('-'*100)
    # 가격정보 존재하면 진행
    if 'price' in tmp:
        prices = tmp['price']
    # 1. 소매인 경우
    ## 1-1 도/소매 같이 나온 경우
    if type(prices)==list:
    
        for data in prices:
            if data['productclscode'] == '01':  # 소매
                # 2. tmp_df
                tmp_df = json_normalize(data['item'])

                
                # 부족한 데이터 추가
                start = tmp_df.iloc[0,:]['yyyy']
                if start != '2012':
                    rows = [ [str(yyyy)] + ['-']*13 for yyyy in range(2012, int(start))]
                    add_df = pd.DataFrame(data=rows, columns = ['yyyy','m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12','yearavg'] )

                    tmp_df = pd.concat([add_df, tmp_df])

                end = tmp_df.iloc[-1,:]['yyyy']
                if end != '2022':
                    rows = [ [str(yyyy)] + ['-']*13 for yyyy in range(int(end)+1, 2023)]
                    add_df = pd.DataFrame(data=rows, columns = ['yyyy','m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12','yearavg'] )

                    tmp_df = pd.concat([tmp_df, add_df])

                tmp_df = tmp_df.reset_index(drop=True)                

         
                
                # 데이터 개수
                years = list(tmp_df.loc[:,'yyyy'])
                years.sort()
                # print(years)
                # 1. 카테고리, 품목, 상품, 등급, 단위용량, 단위명
                meta.append(data['caption'].split('>'))
                cate =  data['caption'].split('>')[1].strip()
                mid_cate =  data['caption'].split('>')[2].strip()
                small_cate =  data['caption'].split('>')[3].strip()
                grad  = data['caption'].split('>')[4].strip()
                volume =  data['caption'].split('>')[5].strip()
                
                # volume은 20kg 과 같이 되어있는데, 이를 20, kg 으로 분리하기
                per_v = ''
                u = ''
                for i in range(len(volume)):
                    cur = volume[i]
                    if ord(cur) in set(range(48,58)): # '0' ~ '9'
                        per_v += cur
                    else:
                        u += cur
                category.extend(         [cate]*      (len(years)*12)        )
                mid_category.extend(     [mid_cate]*  (len(years)*12)    )
                small_category.extend(   [small_cate]*(len(years)*12)  )
                grade.extend(            [grad]*      (len(years)*12)        )
                per_volume.extend(       [per_v]*     (len(years)*12)       )
                measure.extend(             [u]*      (len(years)*12)           )
                
                ## 2-1 year 가져오기
                for yyyy in years:
                    year.extend([yyyy]*12)
                
                ## 2-2 month 가져오기
                tmp = ['01','02','03','04','05','06','07','08','09','10','11','12']*len(years)
                for i in range(len(years)):
                    yyyy = years[i]
                    for j in range(i*12, i*12 + 12):
                        mm = tmp[j]
                        yyyy_mm_dd = str(yyyy) +'-' + mm + '-' +'01'
                        tmp[j] = yyyy_mm_dd
                month.extend(tmp)
                ## 2-3 price 가져오기
                for yyyy in range(len(years)):
                    try :
                        price.extend(list(tmp_df.loc[yyyy,months]))
                    except KeyError:
                        print(yyyy)
                        print(tmp_df)
                        print(price)
                        # print(tmp_df.loc[yyyy,months])
                    
    ## 1-2 1개만 나온 경우
    else:
        data = prices
        if data['productclscode'] == '01':  # 소매
            # 2. tmp_df
            tmp_df = json_normalize(data['item'])

            # 부족한 데이터 추가
            start = tmp_df.iloc[0,:]['yyyy']
            if start != '2012':
                rows = [ [str(yyyy)] + ['-']*13 for yyyy in range(2012, int(start))]
                add_df = pd.DataFrame(data=rows, columns = ['yyyy','m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12','yearavg'] )

                tmp_df = pd.concat([add_df, tmp_df])

            end = tmp_df.iloc[-1,:]['yyyy']
            if end != '2022':
                rows = [ [str(yyyy)] + ['-']*13 for yyyy in range(int(end)+1, 2023)]
                add_df = pd.DataFrame(data=rows, columns = ['yyyy','m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12','yearavg'] )

                tmp_df = pd.concat([tmp_df, add_df])
            tmp_df = tmp_df.reset_index(drop=True)
            
            # 데이터 개수
            years = list(tmp_df.loc[:,'yyyy'])
            years.sort()
            # print(years)
            # 1. 카테고리, 품목, 상품, 등급, 단위용량, 단위명
            meta.append(data['caption'].split('>'))
            cate =  data['caption'].split('>')[1].strip()
            mid_cate =  data['caption'].split('>')[2].strip()
            small_cate =  data['caption'].split('>')[3].strip()
            grad  = data['caption'].split('>')[4].strip()
            volume =  data['caption'].split('>')[5].strip()
            
            # volume은 20kg 과 같이 되어있는데, 이를 20, kg 으로 분리하기
            per_v = ''
            u = ''
            for i in range(len(volume)):
                cur = volume[i]
                if ord(cur) in set(range(48,58)): # '0' ~ '9'
                    per_v += cur
                else:
                    u += cur
            category.extend(         [cate]*(len(years)*12)        )
            mid_category.extend(     [mid_cate]*(len(years)*12)    )
            small_category.extend(   [small_cate]*(len(years)*12)  )
            grade.extend(            [grad]*(len(years)*12)        )
            per_volume.extend(       [per_v]*(len(years)*12)       )
            measure.extend(             [u]*(len(years)*12)           )
            
            ## 2-1 year 가져오기
            for yyyy in years:
                year.extend([yyyy]*12)
            print(year)
            ## 2-2 month 가져오기
            tmp = ['01','02','03','04','05','06','07','08','09','10','11','12']*len(years)
            for i in range(len(years)):
                yyyy = years[i]
                for j in range(i*12, i*12 + 12):
                    mm = tmp[j]
                    yyyy_mm_dd = str(yyyy) +'-' + mm + '-' +'01'
                    tmp[j] = yyyy_mm_dd
            month.extend(tmp)
            ## 2-3 price 가져오기
            for yyyy in range(len(years)):
                price.extend(list(tmp_df.loc[yyyy,months]))
# Out:
# [{'p_cert_id': '2775', 'p_cert_key': 'fca8d024-c5e4-4f48-bdb0-51a1a41bde9b', 'p_returntype': 'json', 'p_yyyy': '2022', 'p_period': '10', 'p_itemcategorycode': '100', 'p_itemcode': '111', 'p_kindcode': '01', 'p_graderank': '1', 'p_countycode': []}]
# 000
# dict_keys(['condition', 'error_code', 'price'])
# ----------------------------------------------------------------------------------------------------
# [{'p_cert_id': '2775', 'p_cert_key': 'fca8d024-c5e4-4f48-bdb0-51a1a41bde9b', 'p_returntype': 'json', 'p_yyyy': '2022', 'p_period': '10', 'p_itemcategorycode': '100', 'p_itemcode': '112', 'p_kindcode': '01', 'p_graderank': '1', 'p_countycode': []}]
# 000
# dict_keys(['condition', 'error_code', 'price'])
# ----------------------------------------------------------------------------------------------------
# ...

# %%
pprint.pprint(meta)
len(meta)

# %% [markdown]
# ### (2) 데이터 조작 및 저장 to Dataframe

# %% [markdown]
# #### df 생성, 값 int로 바꾸기, column 채우기

# %%
### 1. result dataframe 생성
pdf = pd.DataFrame(columns = ['category', 'product','unit','measure', 'weight', 'img',  'goods', '등급', 'date_type','research_date','price'])


### 2. price 가 str이라 이를 nan과 int로 바꿔주기
import numpy as np
for i in range(len(price)):
    p = price[i]
    if p == '-':
        p = np.nan
    else:
        p = int(p.replace(',',''))
    price[i] = p


### 3. 임시 컬럼 값
weight = [0.0]*len(category)
img = [name + '_img' for name in mid_category]
date_type = ['m']*len(category)


### 4. column 넣기
pdf['category'] = category
pdf['product'] = mid_category
pdf['unit'] = per_volume
pdf['measure'] = measure
pdf['weight'] = weight
pdf['img'] = img

pdf['goods'] = small_category
pdf['등급'] = grade
pdf['date_type'] = date_type
pdf['research_date'] = month
pdf['price'] = price

pdf
# Out:
#      category product unit measure  weight     img goods  등급 date_type  \
# 0        식량작물       쌀   20      kg     0.0   쌀_img   일반계  상품         m
# 1        식량작물       쌀   20      kg     0.0   쌀_img   일반계  상품         m
# 2        식량작물       쌀   20      kg     0.0   쌀_img   일반계  상품         m
# 3        식량작물       쌀   20      kg     0.0   쌀_img   일반계  상품         m
# 4        식량작물       쌀   20      kg     0.0   쌀_img   일반계  상품         m
# ...       ...     ...  ...     ...     ...     ...   ...  ..       ...
# 8443      과일류      망고    1       개     0.0  망고_img    수입  상품         m
# 8444      과일류      망고    1       개     0.0  망고_img    수입  상품         m
# 8445      과일류      망고    1       개     0.0  망고_img    수입  상품         m
# 8446      과일류      망고    1       개     0.0  망고_img    수입  상품         m
# 8447      과일류      망고    1       개     0.0  망고_img    수입  상품         m
#
#      research_date    price
# 0       2012-01-01  43876.0
# 1       2012-02-01  44031.0
# ...

# %%
cd /content/drive/MyDrive/Team_lemonmul/PopData/Data/월별데이터(10년)
# Out:
# /content/drive/.shortcut-targets-by-id/1k2RzEvWtJ__WV4ThLWM5VyXk_FspqjfH/Team_lemonmul/PopData/Data/월별데이터(10년)

# %%
pdf.to_csv('농산물유통정보_월데이터_10년_null처리전.csv',header=True, index=False)

# %%
import pandas as pd
pdf = pd.read_csv('농산물유통정보_월데이터_10년_null처리전.csv')
pdf
# Out:
#      category product  unit measure  weight     img goods  등급 date_type  \
# 0        식량작물       쌀    20      kg     0.0   쌀_img   일반계  상품         m
# 1        식량작물       쌀    20      kg     0.0   쌀_img   일반계  상품         m
# 2        식량작물       쌀    20      kg     0.0   쌀_img   일반계  상품         m
# 3        식량작물       쌀    20      kg     0.0   쌀_img   일반계  상품         m
# 4        식량작물       쌀    20      kg     0.0   쌀_img   일반계  상품         m
# ...       ...     ...   ...     ...     ...     ...   ...  ..       ...
# 8443      과일류      망고     1       개     0.0  망고_img    수입  상품         m
# 8444      과일류      망고     1       개     0.0  망고_img    수입  상품         m
# 8445      과일류      망고     1       개     0.0  망고_img    수입  상품         m
# 8446      과일류      망고     1       개     0.0  망고_img    수입  상품         m
# 8447      과일류      망고     1       개     0.0  망고_img    수입  상품         m
#
#      research_date    price
# 0       2012-01-01  43876.0
# 1       2012-02-01  44031.0
# ...

# %% [markdown]
# ## [2] 데이터 전처리

# %% [markdown]
# ### (1) goods name 수정해주기

# %% [markdown]
# #### (a) 괄호 넣어주기 - 예 : 쌀(일반계)
# + 쌀, 찹쌀 - 일반계
# + 생강 - 국산
# + 고춧가루 - 국산
# + 땅콩 - 국산
# + 땅콩 - 수입
# + 사과 - 후지
# + 배 - 신고
# + 참다래 - 국산
# + 참다래 - 그린 뉴질랜드
# + 포도 - 캠벨얼리
# + 피망 - 청
# + 고구마 - 밤
# + 감자 - 수미
# + 상추 - 적
# + 당근 - 무세척
# + 오렌지 - 네이블 미국
# + 레몬 - 수입
# + 체리 - 수입
# + 건포도 - 수입
# + 건블루베리 - 수입
# + 망고 - 수입
#
# #### 수정   - 예 : 가시오이
# + 오이 - 가시계통   -> 가시오이
# + 참깨 - 백색(국산) -> 백색참깨(국산)

# %%
bracket_lst = \
['쌀',
'찹쌀',
'생강',
'고춧가루',
'땅콩',
'사과',
'배',
'참다래',
'포도',
'피망' ,
'고구마',
'감자',
'상추',
'당근',
'오렌지',
'레몬',
'체리',
'건포도' ,
'건블루베리' ,
'망고']

modify = {'오이':'가시오이', '참깨':'백색참깨(국산)'}

for i in range(len(pdf)):
    if pdf.loc[i,'product'] in bracket_lst:
        pdf.loc[i,'goods'] = f"{pdf.loc[i,'product']}({pdf.loc[i,'goods']})"
    
    elif pdf.loc[i,'product'] in modify:
        pdf.loc[i,'goods'] = modify[pdf.loc[i,'product']]
pdf
# Out:
#      category product  unit measure  weight     img   goods  등급 date_type  \
# 0        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 1        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 2        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 3        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 4        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# ...       ...     ...   ...     ...     ...     ...     ...  ..       ...
# 8443      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8444      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8445      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8446      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8447      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
#
#      research_date    price
# 0       2012-01-01  43876.0
# ...

# %% [markdown]
# ### (2) 배추 & 무 & 귤 product 합치기 & 깐마늘(국산) 바꾸기

# %%
### 상품이름 변환
baechu = pdf[pdf['product']=='배추']
baechu = baechu.replace(['봄','월동','고랭지','가을'],'배추')  # 상품 이름을 배추로 통일시키기


mu = pdf[pdf['product']=='무']
mu = mu.replace(['봄','월동','고랭지','가을'],'무')            # 상품 이름을 무로 통일시키기


gyul = pdf[pdf['product']=='감귤']
gyul = gyul.replace(['시설','노지'],'감귤')                   # 상품 이름을 감귤로 통일시키기

# %%
### groupby로 평균내기
baechu_group = baechu.groupby(['category', 'product','unit','measure', 'weight', 'img',  'goods', '등급', 'date_type','research_date']).mean()
mu_group     =     mu.groupby(['category', 'product','unit','measure', 'weight', 'img',  'goods', '등급', 'date_type','research_date']).mean()
gyul_group = gyul.groupby(['category', 'product','unit','measure', 'weight', 'img',  'goods', '등급', 'date_type','research_date']).mean()


### multiindex 접근
tmp = baechu_group.xs('상품', level='등급')
tmp.info()

### multiindex 삭제
baechu_group = baechu_group.reset_index()
mu_group = mu_group.reset_index()
gyul_group = gyul_group.reset_index()
mu_group
baechu_group
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 132 entries, ('채소류', '배추', 1, '포기', 0.0, '배추_img', '배추', 'm', '2012-01-01') to ('채소류', '배추', 1, '포기', 0.0, '배추_img', '배추', 'm', '2022-12-01')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   129 non-null    float64
# dtypes: float64(1)
# memory usage: 3.9+ KB
#     category product  unit measure  weight     img goods  등급 date_type  \
# 0        채소류      배추     1      포기     0.0  배추_img    배추  상품         m
# 1        채소류      배추     1      포기     0.0  배추_img    배추  상품         m
# 2        채소류      배추     1      포기     0.0  배추_img    배추  상품         m
# 3        채소류      배추     1      포기     0.0  배추_img    배추  상품         m
# 4        채소류      배추     1      포기     0.0  배추_img    배추  상품         m
# ..       ...     ...   ...     ...     ...     ...   ...  ..       ...
# 127      채소류      배추     1      포기     0.0  배추_img    배추  상품         m
# ...

# %%
pdf['product'] = pdf['product'].replace('깐마늘(국산)','깐마늘')
pdf[pdf['product'] == '깐마늘']
# Out:
#      category product  unit measure  weight          img    goods  등급  \
# 4884      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 4885      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 4886      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 4887      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 4888      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# ...       ...     ...   ...     ...     ...          ...      ...  ..
# 5011      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 5012      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 5013      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 5014      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
# 5015      채소류     깐마늘     1      kg     0.0  깐마늘(국산)_img  깐마늘(국산)  상품
#
#      date_type research_date    price
# 4884         m    2012-01-01   6792.0
# 4885         m    2012-02-01   7114.0
# ...

# %% [markdown]
# ### (3) 기존 DataFrame에 합치기

# %%
### 기존 DataFrame에서 배추, 무, 감귤 삭제하기
pdf = pdf[pdf['product'] !='배추']
pdf = pdf[pdf['product'] !='무']
pdf = pdf[pdf['product'] !='감귤']
pdf
# Out:
#      category product  unit measure  weight     img   goods  등급 date_type  \
# 0        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 1        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 2        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 3        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 4        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# ...       ...     ...   ...     ...     ...     ...     ...  ..       ...
# 8443      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8444      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8445      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8446      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
# 8447      과일류      망고     1       개     0.0  망고_img  망고(수입)  상품         m
#
#      research_date    price
# 0       2012-01-01  43876.0
# ...

# %%
### 전처리된 배추 & 무 & 귤을 기존 DataFrame에 넣기
import pandas as pd
pdf = pd.concat([pdf, baechu_group, mu_group, gyul_group], axis=0)
pdf = pdf.reset_index().drop('index',axis=1) # index 새로 배열하기
pdf
# Out:
#      category product  unit measure  weight     img   goods  등급 date_type  \
# 0        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 1        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 2        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 3        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# 4        식량작물       쌀    20      kg     0.0   쌀_img  쌀(일반계)  상품         m
# ...       ...     ...   ...     ...     ...     ...     ...  ..       ...
# 7519      과일류      감귤    10       개     0.0  감귤_img      감귤  S과         m
# 7520      과일류      감귤    10       개     0.0  감귤_img      감귤  S과         m
# 7521      과일류      감귤    10       개     0.0  감귤_img      감귤  S과         m
# 7522      과일류      감귤    10       개     0.0  감귤_img      감귤  S과         m
# 7523      과일류      감귤    10       개     0.0  감귤_img      감귤  S과         m
#
#      research_date    price
# 0       2012-01-01  43876.0
# ...

# %% [markdown]
# ### (4) 쌀 데이터 unit 변경 (20kg->1kg)

# %%
for i in pdf[pdf['product']=='쌀'].index:
    cur_unit = pdf.loc[i,'unit']
    multi = 1 / cur_unit
    pdf.loc[i,'unit'] = 1
    pdf.loc[i,'price'] *= multi

# %% [markdown]
# ### (5) price를 round( , 1)

# %%
for i in range(len(pdf)):
    pdf.loc[i,'price'] = round(pdf.loc[i,'price'],1)

# %% [markdown]
# ### (6) null 처리

# %%
### nan 여부 확인
np.isnan(pdf.loc[6947,'price'])
# Out:
# False

# %%
pdf['rep_price'] = pdf['price']

# %%
import numpy as np
for i in range(len(pdf)):
    # print(i)
    cur = pdf.loc[i,'rep_price']
    # 1. 현재가 nan인 경우
    if np.isnan(cur):
        ## [1]  만약 df의 맨 앞이라면 or df맨 앞 제외한, 각 상품의 맨 앞인 경우
        if i == 0 or (pdf.loc[i-1,'product'] != pdf.loc[i,'product']):
            # nan이 아닌 가장 가까운 값가져와서 다 채우기
            j = 1
            while np.isnan(pdf.loc[i+j,'rep_price']):
         
                j += 1
            
            replace = pdf.loc[i+j,'rep_price']
            # 대체하기
            j -= 1
            while j >= 0 :
                pdf.loc[i+j,'rep_price'] = replace
                j -= 1
        
        ## [2] 각 상품의 맨 앞이 아닌 경우 -> 바로 앞의 값으로 대체
        else:
            pdf.loc[i,'rep_price'] = pdf.loc[i-1,'rep_price']

# %% [markdown]
# ### (7) 데이터 저장

# %% [markdown]
# #### (a) dataframe 저장

# %%
pdf.to_csv('농산물유통정보_월데이터_10년_1차전처리후.csv',header=True, index=False)

# %% [markdown]
# #### (b) goods name dictionary로 저장

# %%
pdf['goods'].unique()
# Out:
# array(['쌀(일반계)', '찹쌀(일반계)', '흰 콩(국산)', '붉은 팥(국산)', '국산', '고구마(밤)',
#        '감자(수미)', '양배추', '시금치', '상추(적)', '얼갈이배추', '수박', '참외', '가시오이',
#        '애호박', '토마토', '딸기', '당근(무세척)', '열무', '풋고추', '붉은고추', '양파', '대파',
#        '생강(국산)', '고춧가루(국산)', '깻잎', '피망(청)', '파프리카', '멜론', '깐마늘(국산)',
#        '방울토마토', '백색참깨(국산)', '땅콩(국산)', '땅콩(수입)', '애느타리버섯', '팽이버섯', '새송이버섯',
#        '수입', '사과(후지)', '배(신고)', '백도', '포도(캠벨얼리)', '단감', '참다래(국산)',
#        '참다래(그린 뉴질랜드)', '오렌지(네이블 미국)', '레몬(수입)', '체리(수입)', '건포도(수입)',
#        '건블루베리(수입)', '망고(수입)', '배추', '무', '감귤'], dtype=object)

# %%
### dictionary 생성
product_goods_dict = {}
for i in range(len(pdf)):
    cur_product = pdf.loc[i,'product']
    if cur_product in product_goods_dict:
        cur_goods = pdf.loc[i,'goods']
        if cur_goods not in product_goods_dict[cur_product]:
            product_goods_dict[cur_product].append(cur_goods)

    else:
        product_goods_dict[cur_product] = [pdf.loc[i,'goods']]

# %%
product_goods_dict
# Out:
# {'쌀': ['쌀(일반계)'],
#  '찹쌀': ['찹쌀(일반계)'],
#  '콩': ['흰 콩(국산)'],
#  '팥': ['붉은 팥(국산)'],
#  '녹두': ['국산'],
#  '고구마': ['고구마(밤)'],
#  '감자': ['감자(수미)'],
#  '양배추': ['양배추'],
#  '시금치': ['시금치'],
#  '상추': ['상추(적)'],
#  '얼갈이배추': ['얼갈이배추'],
#  '수박': ['수박'],
#  '참외': ['참외'],
#  '오이': ['가시오이'],
#  '호박': ['애호박'],
#  '토마토': ['토마토'],
#  '딸기': ['딸기'],
#  '당근': ['당근(무세척)'],
#  '열무': ['열무'],
#  '풋고추': ['풋고추'],
#  '붉은고추': ['붉은고추'],
#  '양파': ['양파'],
#  '파': ['대파'],
#  '생강': ['생강(국산)'],
#  '고춧가루': ['고춧가루(국산)'],
#  '깻잎': ['깻잎'],
#  '피망': ['피망(청)'],
#  '파프리카': ['파프리카'],
#  '멜론': ['멜론'],
#  '깐마늘': ['깐마늘(국산)'],
#  '방울토마토': ['방울토마토'],
#  '참깨': ['백색참깨(국산)'],
#  '땅콩': ['땅콩(국산)', '땅콩(수입)'],
#  '느타리버섯': ['애느타리버섯'],
#  '팽이버섯': ['팽이버섯'],
#  '새송이버섯': ['새송이버섯'],
#  '호두': ['수입'],
#  '아몬드': ['수입'],
#  '사과': ['사과(후지)'],
#  '배': ['배(신고)'],
#  '복숭아': ['백도'],
#  '포도': ['포도(캠벨얼리)'],
#  '단감': ['단감'],
#  '바나나': ['수입'],
#  '참다래': ['참다래(국산)', '참다래(그린 뉴질랜드)'],
#  '파인애플': ['수입'],
#  '오렌지': ['오렌지(네이블 미국)'],
#  '레몬': ['레몬(수입)'],
# ...

# %%
cd /content/drive/MyDrive/Team_lemonmul/PopData/Data/월별데이터(10년)
# Out:
# /content/drive/.shortcut-targets-by-id/1k2RzEvWtJ__WV4ThLWM5VyXk_FspqjfH/Team_lemonmul/PopData/Data/월별데이터(10년)

# %%
# pickle로 dictionary 저장
import pickle
with open('product_goods_dict.pickle','wb') as fw:
    pickle.dump(product_goods_dict, fw)

# %% [markdown]
# ## [3] 데이터 전처리 2 - product table 만들기
# + 곡류 - 9
# + 채소  - 10
# + 견과류 - 11
# + 과일  - 12

# %% [markdown]
# ### (1) category_id, product_id 넣기

# %%
### 품목 고르기
gok_ryu = ['쌀', '찹쌀', '콩', '팥', '녹두']  # 8

veg = ['고구마', '감자', '양배추', '시금치', '상추',
       '얼갈이배추', '수박', '참외', '오이', '호박', '토마토', '딸기', '당근', '열무', '풋고추',
       '붉은고추', '양파', '파', '생강', '고춧가루', '깻잎', '피망', '파프리카', '멜론',
       '깐마늘', '방울토마토','느타리버섯', '팽이버섯', '새송이버섯','배추', '무']   # 9


nuts = [ '참깨', '땅콩', '땅콩','호두', '아몬드']   # 10

fruit = [ '사과', '배', '복숭아', '포도', '단감', '참다래', '참다래', '파인애플',   
       '오렌지', '레몬', '체리', '건포도', '건블루베리', '망고', '감귤','바나나']    # 11

# %%
product_table = pdf.copy()
product_table = product_table[['category', 'product', 'unit','measure','weight','img',]]
product_table = product_table.drop_duplicates()  # 중복행 삭제
product_table = product_table.reset_index(drop=True) # index 초기화 #.drop('index',axis=1)  

product_table.insert(0,'category_id',[-1]*len(product_table))
product_table.insert(2,'product_id',[-1]*len(product_table))
product_table
# Out:
#     category_id category  product_id product  unit measure  weight  \
# 0            -1     식량작물          -1       쌀     1      kg     0.0
# 1            -1     식량작물          -1      찹쌀     1      kg     0.0
# 2            -1     식량작물          -1       콩   500       g     0.0
# 3            -1     식량작물          -1       팥   500       g     0.0
# 4            -1     식량작물          -1      녹두   500       g     0.0
# 5            -1     식량작물          -1     고구마     1      kg     0.0
# 6            -1     식량작물          -1      감자   100       g     0.0
# 7            -1      채소류          -1     양배추     1      포기     0.0
# 8            -1      채소류          -1     시금치     1      kg     0.0
# 9            -1      채소류          -1      상추   100       g     0.0
# 10           -1      채소류          -1   얼갈이배추     1      kg     0.0
# 11           -1      채소류          -1      수박     1       개     0.0
# 12           -1      채소류          -1      참외    10       개     0.0
# ...

# %%
### id 넣기
### category_id
for i in range(len(product_table)):
    if product_table.loc[i,'product'] in gok_ryu:
        product_table.loc[i,'category'] = '곡류'
        product_table.loc[i,'category_id'] = '8'
    
    elif product_table.loc[i,'product'] in veg:
        product_table.loc[i,'category'] = '채소'
        product_table.loc[i,'category_id'] = '9'
    
    elif product_table.loc[i,'product'] in nuts:
        product_table.loc[i,'category'] = '견과류'
        product_table.loc[i,'category_id'] = '10'

    elif product_table.loc[i,'product'] in fruit:
        product_table.loc[i,'category'] = '과일'
        product_table.loc[i,'category_id'] = '11'


### product_id
for i in range(len(product_table)):
    product_table.loc[i,'product_id'] = str(i + 1000)
product_table
# Out:
#    category_id category product_id product  unit measure  weight          img
# 0            8       곡류       1000       쌀     1      kg     0.0        쌀_img
# 1            8       곡류       1001      찹쌀     1      kg     0.0       찹쌀_img
# 2            8       곡류       1002       콩   500       g     0.0        콩_img
# 3            8       곡류       1003       팥   500       g     0.0        팥_img
# 4            8       곡류       1004      녹두   500       g     0.0       녹두_img
# 5            9       채소       1005     고구마     1      kg     0.0      고구마_img
# 6            9       채소       1006      감자   100       g     0.0       감자_img
# 7            9       채소       1007     양배추     1      포기     0.0      양배추_img
# 8            9       채소       1008     시금치     1      kg     0.0      시금치_img
# 9            9       채소       1009      상추   100       g     0.0       상추_img
# 10           9       채소       1010   얼갈이배추     1      kg     0.0    얼갈이배추_img
# ...

# %% [markdown]
# ### (2) weight 넣기

# %%
weight_dict = {
    '쌀'                    :	1.35,
'찹쌀'                  :	0.117,
'콩'                    :    0.2,
'팥'                    :	0.167,
'녹두'                  :0.167,
'고구마'                :	0.3,
'감자'                  :3.833,
'배추'                  :	0.633,
'시금치'                :	0.233,
'상추'                  :   1.333,
'얼갈이배추'            :	0.217,
'수박'                  :	0.817,
'참외'                  :	3.883,
'오이'                  :	0.202,
'호박'                  :	1.667,
'토마토'                :	0.5,
'딸기'                  :	8,
'무'                    :	0.75,
'당근'                  :	0.633,
'열무'                  :0.267,
'풋고추'                : 0.767,
'붉은고추'              :	0.683,
'깐마늘'                :	0.433,
'양파'                  : 0.917,
'파'                    :	0.433,
'생강'                  :	0.067,
'고춧가루'              :	0.233,
'깻잎'                  :1.167,
'피망'                  :0.383,
'파프리카'              :	1,
'멜론'                  :	0.333,
'방울토마토'            :	0.917,
'양배추'                :	0.3,
'느타리버섯'            :	1.5,
'팽이버섯'              :1.5,
'새송이버섯'            :	3,
'참깨'                  :	0.25,
'호두'                  : 0.417,
'아몬드'                : 1,
'사과'                  : 	0.4,
'배'                    : 	0.067,
'복숭아'                :	0.6,
'포도'                  :	0.933,
'감귤'                  :	2.167,
'단감'                  :	0.517,
'바나나'                :	2,
'파인애플'              :	1.033,
'오렌지'                :	0.65,
'레몬'                  :0.067,
'체리'                  :	1.183,
'건포도'                :	0.2,
'건블루베리'            :	0.533,
'망고'                  : 0.217,
'땅콩'                  : 0.517,
'참다래'                :	0.383}

weight_dict
# Out:
# {'쌀': 1.35,
#  '찹쌀': 0.117,
#  '콩': 0.2,
#  '팥': 0.167,
#  '녹두': 0.167,
#  '고구마': 0.3,
#  '감자': 3.833,
#  '배추': 0.633,
#  '시금치': 0.233,
#  '상추': 1.333,
#  '얼갈이배추': 0.217,
#  '수박': 0.817,
#  '참외': 3.883,
#  '오이': 0.202,
#  '호박': 1.667,
#  '토마토': 0.5,
#  '딸기': 8,
#  '무': 0.75,
#  '당근': 0.633,
#  '열무': 0.267,
#  '풋고추': 0.767,
#  '붉은고추': 0.683,
#  '깐마늘': 0.433,
#  '양파': 0.917,
#  '파': 0.433,
#  '생강': 0.067,
#  '고춧가루': 0.233,
#  '깻잎': 1.167,
#  '피망': 0.383,
#  '파프리카': 1,
#  '멜론': 0.333,
#  '방울토마토': 0.917,
#  '양배추': 0.3,
#  '느타리버섯': 1.5,
#  '팽이버섯': 1.5,
#  '새송이버섯': 3,
#  '참깨': 0.25,
#  '호두': 0.417,
#  '아몬드': 1,
#  '사과': 0.4,
#  '배': 0.067,
#  '복숭아': 0.6,
#  '포도': 0.933,
#  '감귤': 2.167,
#  '단감': 0.517,
#  '바나나': 2,
#  '파인애플': 1.033,
#  '오렌지': 0.65,
#  '레몬': 0.067,
#  '체리': 1.183,
#  '건포도': 0.2,
#  '건블루베리': 0.533,
#  '망고': 0.217,
#  '땅콩': 0.517,
#  '참다래': 0.383}

# %%
for i in range(len(product_table)):
    product_table.loc[i,'weight'] = weight_dict[product_table.loc[i,'product']]
product_table
# Out:
#    category_id category product_id product  unit measure  weight          img
# 0            8       곡류       1000       쌀     1      kg   1.350        쌀_img
# 1            8       곡류       1001      찹쌀     1      kg   0.117       찹쌀_img
# 2            8       곡류       1002       콩   500       g   0.200        콩_img
# 3            8       곡류       1003       팥   500       g   0.167        팥_img
# 4            8       곡류       1004      녹두   500       g   0.167       녹두_img
# 5            9       채소       1005     고구마     1      kg   0.300      고구마_img
# 6            9       채소       1006      감자   100       g   3.833       감자_img
# 7            9       채소       1007     양배추     1      포기   0.300      양배추_img
# 8            9       채소       1008     시금치     1      kg   0.233      시금치_img
# 9            9       채소       1009      상추   100       g   1.333       상추_img
# 10           9       채소       1010   얼갈이배추     1      kg   0.217    얼갈이배추_img
# ...

# %% [markdown]
# ### (3) product table 저장 & id 저장

# %%
cd /content/drive/MyDrive/Team_lemonmul/PopData/Data/월별데이터(10년)
# Out:
# /content/drive/.shortcut-targets-by-id/1k2RzEvWtJ__WV4ThLWM5VyXk_FspqjfH/Team_lemonmul/PopData/Data/월별데이터(10년)

# %%
product_table.drop('category',axis=1, inplace=True)
product_table.rename(columns={'product':'name'}, inplace=True)
product_table
# Out:
#    category_id product_id   name  unit measure  weight          img
# 0            8       1000      쌀     1      kg   1.350        쌀_img
# 1            8       1001     찹쌀     1      kg   0.117       찹쌀_img
# 2            8       1002      콩   500       g   0.200        콩_img
# 3            8       1003      팥   500       g   0.167        팥_img
# 4            8       1004     녹두   500       g   0.167       녹두_img
# 5            9       1005    고구마     1      kg   0.300      고구마_img
# 6            9       1006     감자   100       g   3.833       감자_img
# 7            9       1007    양배추     1      포기   0.300      양배추_img
# 8            9       1008    시금치     1      kg   0.233      시금치_img
# 9            9       1009     상추   100       g   1.333       상추_img
# 10           9       1010  얼갈이배추     1      kg   0.217    얼갈이배추_img
# 11           9       1011     수박     1       개   0.817       수박_img
# 12           9       1012     참외    10       개   3.883       참외_img
# ...

# %%
product_table.to_csv('농산물유통정보_월데이터_10년_품목table.csv',header=True, index=False)

# %%
### id 저장 https://ivorycirrus.github.io/TIL/python-pickle/ 참고

### product : product_id dictionary
tmp = product_table[['product_id', 'product']]
product_productId_dict = { product : product_id for product_id, product in tmp.values }
print(product_productId_dict)

# pickle로 dictionary 저장
import pickle
with open('product_productId_dict_nong.pickle','wb') as fw:
    pickle.dump(product_productId_dict, fw)
# Out:
# {'쌀': '1000', '찹쌀': '1001', '콩': '1002', '팥': '1003', '녹두': '1004', '고구마': '1005', '감자': '1006', '양배추': '1007', '시금치': '1008', '상추': '1009', '얼갈이배추': '1010', '수박': '1011', '참외': '1012', '오이': '1013', '호박': '1014', '토마토': '1015', '딸기': '1016', '당근': '1017', '열무': '1018', '풋고추': '1019', '붉은고추': '1020', '양파': '1021', '파': '1022', '생강': '1023', '고춧가루': '1024', '깻잎': '1025', '피망': '1026', '파프리카': '1027', '멜론': '1028', '깐마늘': '1029', '방울토마토': '1030', '참깨': '1031', '땅콩': '1032', '느타리버섯': '1033', '팽이버섯': '1034', '새송이버섯': '1035', '호두': '1036', '아몬드': '1037', '사과': '1038', '배': '1039', '복숭아': '1040', '포도': '1041', '단감': '1042', '바나나': '1043', '참다래': '1044', '파인애플': '1045', '오렌지': '1046', '레몬': '1047', '체리': '1048', '건포도': '1049', '건블루베리': '1050', '망고': '1051', '배추': '1052', '무': '1053', '감귤': '1054'}

# %% [markdown]
# ## [4] 데이터 전처리 3 - product_price table 만들기(단위용량 맞춰진상태)

# %% [markdown]
# ### (1) product_id 추가

# %%
cd /content/drive/MyDrive/Team_lemonmul/PopData/Data/월별데이터(10년)
# Out:
# /content/drive/.shortcut-targets-by-id/1k2RzEvWtJ__WV4ThLWM5VyXk_FspqjfH/Team_lemonmul/PopData/Data/월별데이터(10년)

# %%
### id 정보 dictionary load
import pickle

# load data
with open('product_productId_dict_nong.pickle', 'rb') as fr:
    product_productId_dict = pickle.load(fr)

# %%
product_price_table = pdf.copy()
product_price_table = product_price_table[['product', 'date_type','research_date','rep_price']]
product_price_table = product_price_table.drop_duplicates()  # 중복행 삭제
product_price_table = product_price_table.reset_index(drop=True) # index 초기화 #.drop('index',axis=1)  

product_price_table.insert(1,'product_id',[-1]*len(product_price_table))
product_price_table

for i in range(len(product_price_table)):
    
    # 입력해주기
    product_price_table.loc[i,'product_id'] = product_productId_dict[product_price_table.loc[i,'product']]

# %%
product_price_table.rename(columns={'rep_price':'price'}, inplace=True)
product_price_table.drop('product', axis=1, inplace=True)
product_price_table
# Out:
#      product_id date_type research_date   price
# 0          1000         m    2012-01-01  2193.8
# 1          1000         m    2012-02-01  2201.6
# 2          1000         m    2012-03-01  2195.0
# 3          1000         m    2012-04-01  2199.8
# 4          1000         m    2012-05-01  2202.6
# ...         ...       ...           ...     ...
# 7519       1054         m    2022-08-01  3079.0
# 7520       1054         m    2022-09-01  3079.0
# 7521       1054         m    2022-10-01  3079.0
# 7522       1054         m    2022-11-01  3079.0
# 7523       1054         m    2022-12-01  3079.0
#
# [7524 rows x 4 columns]

# %% [markdown]
# ### (2) product_price table 저장

# %%
cd /content/drive/MyDrive/Team_lemonmul/PopData/Data/월별데이터(10년)
# Out:
# /content/drive/.shortcut-targets-by-id/1k2RzEvWtJ__WV4ThLWM5VyXk_FspqjfH/Team_lemonmul/PopData/Data/월별데이터(10년)

# %%
product_price_table.to_csv('농산물유통정보_월데이터_10년_품목_가격table.csv',header=True, index=False)
