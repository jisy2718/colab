# %% [markdown]
# # 목적
# + 최신화 된 물가정보를 이용할 수 있도록 하는, 빅데이터를 구하자

# %% [markdown]
# # 쇼핑 API
# + 요청변수 설명
#     + https://developers.naver.com/docs/serviceapi/search/shopping/shopping.md#%EC%87%BC%ED%95%91
#
# + 장보기 부분 나오는 검색어들
#     + (새벽배송 가능상품), SSG 새벽배송, SSG닷컴, 이마트몰, 이마트 트레이더스, Homeplus, GS 프레시몰, 농협하나로마트, 현대백화점 식품관, 현대백화점장보기
#     + 시장관련
#         + 동네시장 장보기, 대전중앙시장 등등 https://shopping.naver.com/market/traditionalmarket?storeId=100839984 들어가면 매우 많음
#
# + 오프라인 몰
#     + 홈플러스

# %%
### 30개 sim으로 가져와서, 최저가 sorting해서, 데이터 저장하기

print(sorted(tmp['items'], key= lambda x: int(x['lprice'])))
# Out:
# [{'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=82951029051', 'image': 'https://shopping-phinf.pstatic.net/main_8295102/82951029051.1.jpg', 'lprice': '690', 'hprice': '', 'mallName': '가온 상사', 'productId': '82951029051', 'productType': '2', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=83309949099', 'image': 'https://shopping-phinf.pstatic.net/main_8330994/83309949099.jpg', 'lprice': '750', 'hprice': '', 'mallName': '오루고유통', 'productId': '83309949099', 'productType': '2', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=84602769168', 'image': 'https://shopping-phinf.pstatic.net/main_8460276/84602769168.jpg', 'lprice': '800', 'hprice': '', 'mallName': 'JI생활식품', 'productId': '84602769168', 'productType': '3', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=27613890523', 'image': 'https://shopping-phinf.pstatic.net/main_2761389/27613890523.20210617144916.jpg', 'lprice': '800', 'hprice': '', 'mallName': '네이버', 'productId': '27613890523', 'productType': '1', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=6359452275', 'image': 'https://shopping-phinf.pstatic.net/main_6359452/6359452275.20120522120901.jpg', 'lprice': '820', 'hprice': '', 'mallName': '네이버', 'productId': '6359452275', 'productType': '1', 'brand': '짜파게티', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=27718449819', 'image': 'https://shopping-phinf.pstatic.net/main_2771844/27718449819.jpg', 'lprice': '820', 'hprice': '', 'mallName': '11번가', 'productId': '27718449819', 'productType': '3', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=29724670596', 'image': 'https://shopping-phinf.pstatic.net/main_2972467/29724670596.jpg', 'lprice': '820', 'hprice': '', 'mallName': '멸치쇼핑', 'productId': '29724670596', 'productType': '3', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=29487734852', 'image': 'https://shopping-phinf.pstatic.net/main_2948773/29487734852.1.jpg', 'lprice': '840', 'hprice': '', 'mallName': '옥션', 'productId': '29487734852', 'productType': '2', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티</b> 컵라면 <b>123g</b> <b>큰사발</b> 큰컵', 'link': 'https://search.shopping.naver.com/gate.nhn?id=83994503844', 'image': 'https://shopping-phinf.pstatic.net/main_8399450/83994503844.jpg', 'lprice': '880', 'hprice': '', 'mallName': 'P제이몰', 'productId': '83994503844', 'productType': '2', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}, {'title': '<b>농심 짜파게티 큰사발 123g</b>', 'link': 'https://search.shopping.naver.com/gate.nhn?id=29833936912', 'image': 'https://shopping-phinf.pstatic.net/main_2983393/29833936912.jpg', 'lprice': '880', 'hprice': '', 'mallName': '인터파크', 'productId': '29833936912', 'productType': '3', 'brand': '농심', 'maker': '농심', 'category1': '식품', 'category2': '라면/면류', 'category3': '라면', 'category4': '컵라면'}]

# %%
### json으로 변환
import json, pprint
tmp = json.loads(response_body.decode('utf-8'))
type(tmp)
pprint.pprint(tmp)
pprint.pprint(tmp['items'][0])
with open('test.json','w', encoding='utf-8') as make_file:
    json.dump(tmp, make_file, ensure_ascii=False, indent='\t')

# %%
# 검색 API 이용해서, 쇼핑검색
import os
import sys
import urllib.request
client_id = "a8DDB5LJUVwh8_MWPtSj"
client_secret = "hKlWjoMufh"
encText = urllib.parse.quote("농심 짜파게티 큰사발 123g")
url = "https://openapi.naver.com/v1/search/shop.json?start=1&display=30&sort=sim&query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/shop.json?start=1&display=10&sort=asc&query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# ### (아래)사용 x

# %%
# 쇼핑인사이트
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
url = "https://openapi.naver.com/v1/datalab/shopping/categories";
body = "{\"startDate\":\"2017-08-01\",\"endDate\":\"2017-09-30\",\"timeUnit\":\"month\",\"category\":[{\"name\":\"패션의류\",\"param\":[\"50000000\"]},{\"name\":\"화장품/미용\",\"param\":[\"50000002\"]}],\"device\":\"pc\",\"ages\":[\"20\",\"30\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2017-08-01","endDate":"2017-09-30","timeUnit":"month","results":[{"title":"패션의류","category":["50000000"],"data":[{"period":"2017-08-01","ratio":84.01252},{"period":"2017-09-01","ratio":100}]},{"title":"화장품/미용","category":["50000002"],"data":[{"period":"2017-08-01","ratio":22.21162},{"period":"2017-09-01","ratio":21.54278}]}]}

# %%
sudo wget https://dlcdn.apache.org/spark/spark-3.2.2/spark-3.2.2-bin-hadoop3.2.tgz
