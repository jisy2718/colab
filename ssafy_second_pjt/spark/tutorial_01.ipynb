# %% [markdown]
# join
#
# filter
#
# RandomSplit
#
# orderBy
#
# df 안짤리게
#
# def show(self, n=20, truncate=True, vertical=False):
# https://signalfix.net/ko/spark-show-%ED%85%8C%EC%9D%B4%EB%B8%94%EC%97%90-dataframe-%EB%82%B4%EC%9A%A9-%ED%91%9C%EC%8B%9C

# %%
cd /content/drive/MyDrive/Colab/ssafy_second_pjt/spark
# Out:
# /content/drive/MyDrive/Colab/ssafy_second_pjt/spark

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.3 MB 41 kB/s
# ...
#      |████████████████████████████████| 199 kB 39.6 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=d4a98f16ff6309badd34deb19729151d441009cb9fbecd8b2ef0f9afb75eb012
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# ...

# %%
import pyspark
import pandas as pd
pdf = pd.read_csv('test1.csv')

# %%
pdf
# Out:
#        Name  age
# 0     Krish   31
# 1  Sudhansh   30
# 2     Sunny   29

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('practice1').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10b41cb62fe2:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>practice1</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sdf = spark.read.csv('test1.csv', header=True, inferSchema=True)

# %%
sdf.show()
print(type(sdf))
# Out:
# +--------+---+
# |    Name|age|
# +--------+---+
# |   Krish| 31|
# |Sudhansh| 30|
# |   Sunny| 29|
# +--------+---+
#
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
print(sdf.toPandas().head())
print(type(sdf.toPandas()))
# Out:
#        Name  age
# 0     Krish   31
# 1  Sudhansh   30
# 2     Sunny   29
# <class 'pandas.core.frame.DataFrame'>

# %%
sdf.head(3)
# Out:
# [Row(Name='Krish', age=31),
#  Row(Name='Sudhansh', age=30),
#  Row(Name='Sunny', age=29)]

# %%
sdf.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
